# %%
# Below codes demonstrating data cleaning (Actual data removed for confidentiality reasons)

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# Importing of data

# %%
df = pd.read_excel('input file directory', sheet_name = 'Fire')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6f5b80a029d8> in <module>()
# ----> 1 df = pd.read_excel('/----/Lead n Opp.xlsx', sheet_name = 'Fire')
#
# NameError: name 'pd' is not defined

# %%
# Cleaning of data

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
# Displaying the columns
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b666bf274d0a> in <module>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
from IPython.display import display

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.notna()
# Out:
#      company  country  description  standard  standard_abb  standard_no  \
# 0       True    False         True      True         False        False
# 1       True    False         True      True         False        False
# 2       True     True         True      True          True         True
# 3      False    False        False      True          True         True
# 4      False    False        False      True          True         True
# 5      False    False        False      True          True         True
# 6       True     True         True      True          True         True
# 7       True     True         True      True          True         True
# 8       True     True         True      True          True         True
# 9       True     True         True      True          True         True
# 10     False    False        False      True          True         True
# 11     False    False        False      True          True         True
# ...

# %%
df_groupby = df.groupby('standard_abb')

# %%
df_groupby.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-936bd28146dc> in <module>()
# ----> 1 df_groupby.count()
#
# NameError: name 'df_groupby' is not defined

# %%
#non_null_columns = [col for col in df.columns if df.loc[:, col].notna().any()]
#df[non_null_columns]

# %%
df = df[[ i for i in df.columns if df.loc[:,i].notna().any() ]]

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df = df.drop(columns = ['client_name' ], axis = 1)

# %%
df = df.loc[: , 'company' : 'enquiry_received_date']

# %%
df.groupby('country')['country'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-99aedab4c712> in <module>()
# ----> 1 df.groupby('country')['country'].nunique()
#
# NameError: name 'df' is not defined

# %%
df.groupby('country').head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-181eb08b958d> in <module>()
# ----> 1 df.groupby('country').head()
#
# NameError: name 'df' is not defined

# %%
df.dropna(subset=['company'], inplace=True)

# %%
df['country'].value_counts().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9dea4b1fc7ba> in <module>()
# ----> 1 df['country'].value_counts().sort_values(ascending=False)
#
# NameError: name 'df' is not defined

# %%
df_gpby_cty = df.groupby('country').count().sort_values(by = 'company', ascending=False)

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-ea8415b8a3ee> in <module>()
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df['standard_abb'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7198b1f506f2> in <module>()
# ----> 1 df['standard_abb'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df[df['standard_abb'] == 'E84']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ad681e3c5fa2> in <module>()
# ----> 1 df[df['standard_abb'] == 'E84']
#
# NameError: name 'df' is not defined

# %%
df['standard_abb'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ea00ec755bfb> in <module>()
# ----> 1 df['standard_abb'].describe()
#
# NameError: name 'df' is not defined

# %%
sns.barplot(x = 'company' , data = df.groupby('country').count().sort_values(by = 'company', ascending=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-49a940fb351f> in <module>()
# ----> 1 sns.barplot(x = 'company' , data = df.groupby('country').count().sort_values(by = 'company', ascending=False))
#
# NameError: name 'sns' is not defined

# %%
sns.countplot( x = df_gpby_cty['standard_abb']     )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-2c0ca6ef8201> in <module>()
# ----> 1 sns.countplot( x = df_gpby_cty['standard_abb']     )
#
# NameError: name 'sns' is not defined

# %%
df_gpby_cty.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c3dcc3b7d411> in <module>()
# ----> 1 df_gpby_cty.describe()
#
# NameError: name 'df_gpby_cty' is not defined

# %%
 sns.countplot(x = 'day' , data = tips)
